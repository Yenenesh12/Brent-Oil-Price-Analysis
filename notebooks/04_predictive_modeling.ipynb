# %% [markdown]
# # Predictive Modeling with VAR and SHAP
#
# ## Business Relevance
# Forecasting future prices and explaining model decisions supports strategic planning in finance.
#
# ## Improvements for Capstone
# - Added VAR for forecasting.
# - SHAP for explainability (rubric requirement).
# - Integration with Streamlit dashboard.

# %%
import sys
sys.path.append('../src')
from predictive_model import PredictiveModel
import pandas as pd
import os

# Load data
df = pd.read_csv('../outputs/data/processed_prices.csv')
df['Date'] = pd.to_datetime(df['Date'])
df = df.dropna(subset=['Price', 'Returns'])

# Fit VAR model
pred_model = PredictiveModel(df)
results = pred_model.fit_var(maxlags=5)
print(results.summary())

# SHAP explainability
shap_values = pred_model.explain_with_shap(n_background=100)
print('SHAP values generated and plot saved.')

# Note: Run Streamlit dashboard to visualize
# streamlit run ../dashboard/streamlit/app.py
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 15, Feb, 2026
# Time:                     17:24:49
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -8.00704
# Nobs:                     9005.00    HQIC:                  -8.01849
# Log likelihood:           10596.8    FPE:                0.000327378
# AIC:                     -8.02440    Det(Omega_mle):     0.000326579
# --------------------------------------------------------------------
# Results for equation Price
# =============================================================================
#                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------
# const              0.038992         0.022848            1.707           0.088
# L1.Price           1.043419         0.017908           58.266           0.000
# L1.Returns        -1.049726         0.862041           -1.218           0.223
# L2.Price          -0.087226         0.025456           -3.427           0.001
# L2.Returns         1.187474         0.862330            1.377           0.168
# L3.Price           0.020792         0.025473            0.816           0.414
# L3.Returns         0.943848         0.862714            1.094           0.274
# L4.Price           0.057439         0.025464            2.256           0.024
# L4.Returns        -0.862768         0.862552           -1.000           0.317
# L5.Price          -0.035057         0.017925           -1.956           0.050
# L5.Returns        -0.390235         0.508043           -0.768           0.442
# =============================================================================
#
# Results for equation Returns
# =============================================================================
#                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------
# const              0.001264         0.000475            2.664           0.008
# L1.Price           0.000858         0.000372            2.306           0.021
# L1.Returns        -0.045948         0.017905           -2.566           0.010
# L2.Price          -0.000656         0.000529           -1.240           0.215
# L2.Returns        -0.032732         0.017911           -1.827           0.068
# L3.Price          -0.000290         0.000529           -0.548           0.584
# L3.Returns         0.009466         0.017919            0.528           0.597
# L4.Price           0.000352         0.000529            0.666           0.505
# L4.Returns        -0.009940         0.017915           -0.555           0.579
# L5.Price          -0.000279         0.000372           -0.750           0.453
# L5.Returns        -0.017675         0.010552           -1.675           0.094
# =============================================================================
#
# Correlation matrix of residuals
#               Price   Returns
# Price      1.000000  0.808288
# Returns    0.808288  1.000000
#
#
#
# Generating model explainability using VAR coefficients...
# ✓ Feature importance plot saved to outputs/figures/var_feature_importance.png
# ✓ Coefficient heatmap saved to outputs/figures/var_coefficient_heatmap.png
#
# Top 10 Most Important Features:
#          feature  importance
# Price_L4.Returns    1.187474
# Price_L2.Returns    1.049726
# Price_L1.Returns    1.043419
# Returns_L1.Price    0.943848
# Returns_L3.Price    0.862768
# Returns_L5.Price    0.390235
# Price_L3.Returns    0.087226
# Returns_L2.Price    0.057439
#   Price_L3.Price    0.045948
#      Price_const    0.038992
# SHAP values generated and plot saved.

# %% [markdown]
# ## Key Insights
# - VAR captures price-return dynamics.
# - SHAP shows feature importance for transparency.
